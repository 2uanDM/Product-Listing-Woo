# %%
data_lst = [
   {
      "type": "simple",
      "sku": "tumbler-bon-20230619-001",
      "name": "Fishing Gigi 40 oz Tumbler With Handle, Steel Cup, Insulated Tumbler With Straw Lid",
      "status": "publish",
      "featured": False,
      "catalog_visibility": "visible",
      "short_description": "",
      "description": "",
      "tax_status": "taxable",
      "stock_status": "instock",
      "backorders": "no",
      "sold_individually": False,
      "regular_price": "",
      "categories": [
         {
            "name": ""
         }
      ],
      "tags": [
         {
            "name": ""
         }
      ],
      "meta_data": [
         {
            "key": "fifu_list_url",
            "value": "https://i.etsystatic.com/24311121/r/il/f8de96/5034176737/il_794xN.5034176737_smjv.jpg|https://i.etsystatic.com/24311121/r/il/72d03f/4845607458/il_794xN.4845607458_gquf.jpg|https://i.etsystatic.com/24311121/r/il/beaed3/4813669816/il_794xN.4813669816_t6er.jpg"
         }
      ]
   },
   {
      "type": "simple",
      "sku": "tumbler-bon-20230619-002",
      "name": "Gradient Distressed Deer, Hunting 40 oz Tumbler With Handle, Steel Cup, Insulated Tumbler With Straw Lid",
      "status": "publish",
      "featured": False,
      "catalog_visibility": "visible",
      "short_description": "",
      "description": "",
      "tax_status": "taxable",
      "stock_status": "instock",
      "backorders": "no",
      "sold_individually": False,
      "regular_price": "",
      "categories": [
         {
            "name": ""
         }
      ],
      "tags": [
         {
            "name": ""
         }
      ],
      "meta_data": [
         {
            "key": "fifu_list_url",
            "value": "https://i.etsystatic.com/24311121/r/il/72d03f/4845607458/il_794xN.4845607458_gquf.jpg|https://i.etsystatic.com/24311121/r/il/beaed3/4813669816/il_794xN.4813669816_t6er.jpg"
         }
      ]
   },
   {
      "type": "simple",
      "sku": "tumbler-bon-20230619-003",
      "name": "Floral Woodland Porcupine 40 oz Tumbler With Handle, Steel Cup, Insulated Tumbler With Straw Lid",
      "status": "publish",
      "featured": False,
      "catalog_visibility": "visible",
      "short_description": "",
      "description": "",
      "tax_status": "taxable",
      "stock_status": "instock",
      "backorders": "no",
      "sold_individually": False,
      "regular_price": "",
      "categories": [
         {
            "name": ""
         }
      ],
      "tags": [
         {
            "name": ""
         }
      ],
      "meta_data": [
         {
            "key": "fifu_list_url",
            "value": "https://i.etsystatic.com/24311121/r/il/beaed3/4813669816/il_794xN.4813669816_t6er.jpg"
         }
      ]
   },
   {
      "type": "simple",
      "sku": "tumbler-bon-20230619-004",
      "name": "Peacock Giant 40 oz Tumbler With Handle, Steel Cup, Insulated Tumbler With Straw Lid",
      "status": "publish",
      "featured": False,
      "catalog_visibility": "visible",
      "short_description": "",
      "description": "",
      "tax_status": "taxable",
      "stock_status": "instock",
      "backorders": "no",
      "sold_individually": False,
      "regular_price": "",
      "categories": [
         {
            "name": ""
         }
      ],
      "tags": [
         {
            "name": ""
         }
      ],
      "meta_data": [
         {
            "key": "fifu_list_url",
            "value": "https://i.etsystatic.com/23856742/r/il/a67cdf/4939896591/il_794xN.4939896591_1cfo.jpg|https://i.etsystatic.com/23856742/r/il/942a89/4891627720/il_794xN.4891627720_ov39.jpg|https://i.etsystatic.com/24311121/r/il/72d03f/4845607458/il_794xN.4845607458_gquf.jpg|https://i.etsystatic.com/24311121/r/il/72d03f/4845607458/il_794xN.4845607458_gquf.jpg"
         }
      ]
   }
]

# %%
for index, data in enumerate(data_lst):
